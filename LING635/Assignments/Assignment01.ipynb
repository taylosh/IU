# %% [markdown]
# # L635-Fall2025-Assignment 1: ESPnet Tutorial
#
# In this tutorial, we will learn how to fine-tune a speech foundation model using ESPnet EZ.
#
# Main references:
# - [ESPnet repository](https://github.com/espnet/espnet)
# - [ESPnet documentation](https://espnet.github.io/espnet/)
# - [ESPnet-EZ repo](https://github.com/espnet/espnet/tree/master/espnetez)
#
# ## Important Notes
# - Please submit PDF files of your completed notebooks to Canvas. You can print the notebook using `File -> Print` in the menu bar.
#
# ## Acknowledgement
# - This homework is adapted from the ESPnet online demos and tutorials.

# %% [markdown]
# ## Install ESPnet
# - We are using a temporary version of ESPNET to avoid compatibility issues for this assignment. You may see some dependency errors. It should be safe for you to ignore them for now.

# %%
# !wget https://github.com/Fhrozen/espnet/archive/refs/heads/pr-numpy.zip
# !unzip pr-numpy.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: espnet-pr-numpy/espnet2/diar/decoder/linear_decoder.py
#   inflating: espnet-pr-numpy/espnet2/diar/espnet_model.py
#   inflating: espnet-pr-numpy/espnet2/diar/label_processor.py
#    creating: espnet-pr-numpy/espnet2/diar/layers/
#  extracting: espnet-pr-numpy/espnet2/diar/layers/__init__.py
#   inflating: espnet-pr-numpy/espnet2/diar/layers/abs_mask.py
#   inflating: espnet-pr-numpy/espnet2/diar/layers/multi_mask.py
#   inflating: espnet-pr-numpy/espnet2/diar/layers/tcn_nomask.py
#    creating: espnet-pr-numpy/espnet2/diar/separator/
#  extracting: espnet-pr-numpy/espnet2/diar/separator/__init__.py
#   inflating: espnet-pr-numpy/espnet2/diar/separator/tcn_separator_nomask.py
#    creating: espnet-pr-numpy/espnet2/enh/
#  extracting: espnet-pr-numpy/espnet2/enh/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/abs_enh.py
#    creating: espnet-pr-numpy/espnet2/enh/decoder/
#  extracting: espnet-pr-numpy/espnet2/enh/decoder/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/decoder/abs_decoder.py
#   inflating: espnet-pr-numpy/espnet2/enh/decoder/conv_decoder.py
#   inflating: espnet-pr-numpy/espnet2/enh/decoder/null_decoder.py
#   inflating: espnet-pr-numpy/espnet2/enh/decoder/stft_decoder.py
#    creating: espnet-pr-numpy/espnet2/enh/diffusion/
#  extracting: espnet-pr-numpy/espnet2/enh/diffusion/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/diffusion/abs_diffusion.py
#    creating: espnet-pr-numpy/espnet2/enh/diffusion/sampling/
#   inflating: espnet-pr-numpy/espnet2/enh/diffusion/sampling/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/diffusion/sampling/correctors.py
#   inflating: espnet-pr-numpy/espnet2/enh/diffusion/sampling/predictors.py
#   inflating: espnet-pr-numpy/espnet2/enh/diffusion/score_based_diffusion.py
#   inflating: espnet-pr-numpy/espnet2/enh/diffusion/sdes.py
#   inflating: espnet-pr-numpy/espnet2/enh/diffusion_enh.py
#    creating: espnet-pr-numpy/espnet2/enh/encoder/
#  extracting: espnet-pr-numpy/espnet2/enh/encoder/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/encoder/abs_encoder.py
#   inflating: espnet-pr-numpy/espnet2/enh/encoder/conv_encoder.py
#   inflating: espnet-pr-numpy/espnet2/enh/encoder/null_encoder.py
#   inflating: espnet-pr-numpy/espnet2/enh/encoder/stft_encoder.py
#   inflating: espnet-pr-numpy/espnet2/enh/espnet_enh_s2t_model.py
#   inflating: espnet-pr-numpy/espnet2/enh/espnet_model.py
#   inflating: espnet-pr-numpy/espnet2/enh/espnet_model_tse.py
#    creating: espnet-pr-numpy/espnet2/enh/extractor/
#  extracting: espnet-pr-numpy/espnet2/enh/extractor/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/extractor/abs_extractor.py
#   inflating: espnet-pr-numpy/espnet2/enh/extractor/td_speakerbeam_extractor.py
#    creating: espnet-pr-numpy/espnet2/enh/layers/
#  extracting: espnet-pr-numpy/espnet2/enh/layers/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/adapt_layers.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/beamformer.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/beamformer_th.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/bsrnn.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/complex_utils.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/complexnn.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/conv_utils.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/dc_crn.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/dcunet.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/dnn_beamformer.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/dnn_wpe.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/dnsmos.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/dpmulcat.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/dprnn.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/dptnet.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/fasnet.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/ifasnet.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/mask_estimator.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/ncsnpp.py
#    creating: espnet-pr-numpy/espnet2/enh/layers/ncsnpp_utils/
#  extracting: espnet-pr-numpy/espnet2/enh/layers/ncsnpp_utils/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/ncsnpp_utils/layers.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/ncsnpp_utils/layerspp.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/ncsnpp_utils/normalization.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/ncsnpp_utils/up_or_down_sampling.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/ncsnpp_utils/upfirdn2d.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/skim.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/swin_transformer.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/tcn.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/tcndenseunet.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/uses.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/uses2_comp.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/uses2_swin.py
#   inflating: espnet-pr-numpy/espnet2/enh/layers/wpe.py
#    creating: espnet-pr-numpy/espnet2/enh/loss/
#  extracting: espnet-pr-numpy/espnet2/enh/loss/__init__.py
#    creating: espnet-pr-numpy/espnet2/enh/loss/criterions/
#  extracting: espnet-pr-numpy/espnet2/enh/loss/criterions/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/criterions/abs_loss.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/criterions/tf_domain.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/criterions/time_domain.py
#    creating: espnet-pr-numpy/espnet2/enh/loss/wrappers/
#  extracting: espnet-pr-numpy/espnet2/enh/loss/wrappers/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/wrappers/abs_wrapper.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/wrappers/dpcl_solver.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/wrappers/fixed_order.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/wrappers/mixit_solver.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/wrappers/multilayer_pit_solver.py
#   inflating: espnet-pr-numpy/espnet2/enh/loss/wrappers/pit_solver.py
#    creating: espnet-pr-numpy/espnet2/enh/separator/
#  extracting: espnet-pr-numpy/espnet2/enh/separator/__init__.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/abs_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/asteroid_models.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/bsrnn_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/conformer_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/dan_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/dc_crn_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/dccrn_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/dpcl_e2e_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/dpcl_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/dprnn_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/dptnet_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/fasnet_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/ineube_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/neural_beamformer.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/rnn_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/skim_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/svoice_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/tcn_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/tfgridnet_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/tfgridnetv2_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/tfgridnetv3_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/transformer_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/uses2_separator.py
#   inflating: espnet-pr-numpy/espnet2/enh/separator/uses_separator.py
#    creating: espnet-pr-numpy/espnet2/fileio/
#  extracting: espnet-pr-numpy/espnet2/fileio/__init__.py
#   inflating: espnet-pr-numpy/espnet2/fileio/datadir_writer.py
#   inflating: espnet-pr-numpy/espnet2/fileio/multi_sound_scp.py
#   inflating: espnet-pr-numpy/espnet2/fileio/npy_scp.py
#   inflating: espnet-pr-numpy/espnet2/fileio/rand_gen_dataset.py
#   inflating: espnet-pr-numpy/espnet2/fileio/read_text.py
#   inflating: espnet-pr-numpy/espnet2/fileio/rttm.py
#   inflating: espnet-pr-numpy/espnet2/fileio/score_scp.py
#   inflating: espnet-pr-numpy/espnet2/fileio/sound_scp.py
#   inflating: espnet-pr-numpy/espnet2/fileio/vad_scp.py
#    creating: espnet-pr-numpy/espnet2/fst/
#  extracting: espnet-pr-numpy/espnet2/fst/__init__.py
#   inflating: espnet-pr-numpy/espnet2/fst/lm_rescore.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/abs_gan_codec.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/dac/
#   inflating: espnet-pr-numpy/espnet2/gan_codec/dac/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/dac/dac.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/encodec/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/encodec/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/encodec/encodec.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/funcodec/
#   inflating: espnet-pr-numpy/espnet2/gan_codec/funcodec/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/funcodec/funcodec.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/hificodec/
#   inflating: espnet-pr-numpy/espnet2/gan_codec/hificodec/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/hificodec/hificodec.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/hificodec/module.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/shared/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/shared/__init__.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/shared/decoder/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/shared/decoder/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/decoder/seanet.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/decoder/seanet_2d.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/shared/discriminator/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/shared/discriminator/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/discriminator/msmpmb_discriminator.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/discriminator/msstft_conv.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/discriminator/msstft_discriminator.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/discriminator/stft_discriminator.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/shared/encoder/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/shared/encoder/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/encoder/seanet.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/encoder/seanet_2d.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/encoder/snake_activation.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/shared/loss/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/shared/loss/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/loss/freq_loss.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/loss/loss_balancer.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/shared/quantizer/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/shared/quantizer/__init__.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/shared/quantizer/modules/
#  extracting: espnet-pr-numpy/espnet2/gan_codec/shared/quantizer/modules/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/quantizer/modules/core_vq.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/quantizer/modules/distrib.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/shared/quantizer/residual_vq.py
#    creating: espnet-pr-numpy/espnet2/gan_codec/soundstream/
#   inflating: espnet-pr-numpy/espnet2/gan_codec/soundstream/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_codec/soundstream/soundstream.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/
#  extracting: espnet-pr-numpy/espnet2/gan_svs/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/abs_gan_svs.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/avocodo/
#   inflating: espnet-pr-numpy/espnet2/gan_svs/avocodo/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/avocodo/avocodo.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/joint/
#   inflating: espnet-pr-numpy/espnet2/gan_svs/joint/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/joint/joint_score2wav.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/pits/
#   inflating: espnet-pr-numpy/espnet2/gan_svs/pits/modules.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/pits/ying_decoder.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/post_frontend/
#   inflating: espnet-pr-numpy/espnet2/gan_svs/post_frontend/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/post_frontend/fused.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/post_frontend/s3prl.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/uhifigan/
#   inflating: espnet-pr-numpy/espnet2/gan_svs/uhifigan/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/uhifigan/sine_generator.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/uhifigan/uhifigan.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/utils/
#   inflating: espnet-pr-numpy/espnet2/gan_svs/utils/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/utils/expand_f0.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/visinger2/
#   inflating: espnet-pr-numpy/espnet2/gan_svs/visinger2/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/visinger2/ddsp.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/visinger2/visinger2_vocoder.py
#    creating: espnet-pr-numpy/espnet2/gan_svs/vits/
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/duration_predictor.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/generator.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/length_regulator.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/modules.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/phoneme_predictor.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/pitch_predictor.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/prior_decoder.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/text_encoder.py
#   inflating: espnet-pr-numpy/espnet2/gan_svs/vits/vits.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/
#  extracting: espnet-pr-numpy/espnet2/gan_tts/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/abs_gan_tts.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/hifigan/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/hifigan/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/hifigan/hifigan.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/hifigan/loss.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/hifigan/residual_block.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/jets/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/jets/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/jets/alignments.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/jets/generator.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/jets/jets.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/jets/length_regulator.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/jets/loss.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/joint/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/joint/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/joint/joint_text2wav.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/melgan/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/melgan/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/melgan/melgan.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/melgan/pqmf.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/melgan/residual_stack.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/parallel_wavegan/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/parallel_wavegan/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/parallel_wavegan/parallel_wavegan.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/parallel_wavegan/upsample.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/style_melgan/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/style_melgan/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/style_melgan/style_melgan.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/style_melgan/tade_res_block.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/utils/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/utils/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/utils/get_random_segments.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/vits/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/duration_predictor.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/flow.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/generator.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/loss.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/vits/monotonic_align/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/monotonic_align/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/monotonic_align/core.pyx
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/monotonic_align/setup.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/posterior_encoder.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/residual_coupling.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/text_encoder.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/transform.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/vits/vits.py
#    creating: espnet-pr-numpy/espnet2/gan_tts/wavenet/
#   inflating: espnet-pr-numpy/espnet2/gan_tts/wavenet/__init__.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/wavenet/residual_block.py
#   inflating: espnet-pr-numpy/espnet2/gan_tts/wavenet/wavenet.py
#    creating: espnet-pr-numpy/espnet2/hubert/
#  extracting: espnet-pr-numpy/espnet2/hubert/__init__.py
#   inflating: espnet-pr-numpy/espnet2/hubert/espnet_model.py
#   inflating: espnet-pr-numpy/espnet2/hubert/hubert_loss.py
#    creating: espnet-pr-numpy/espnet2/iterators/
#  extracting: espnet-pr-numpy/espnet2/iterators/__init__.py
#   inflating: espnet-pr-numpy/espnet2/iterators/abs_iter_factory.py
#   inflating: espnet-pr-numpy/espnet2/iterators/category_chunk_iter_factory.py
#   inflating: espnet-pr-numpy/espnet2/iterators/category_iter_factory.py
#   inflating: espnet-pr-numpy/espnet2/iterators/chunk_iter_factory.py
#   inflating: espnet-pr-numpy/espnet2/iterators/multiple_iter_factory.py
#   inflating: espnet-pr-numpy/espnet2/iterators/sequence_iter_factory.py
#    creating: espnet-pr-numpy/espnet2/layers/
#  extracting: espnet-pr-numpy/espnet2/layers/__init__.py
#   inflating: espnet-pr-numpy/espnet2/layers/abs_normalize.py
#   inflating: espnet-pr-numpy/espnet2/layers/augmentation.py
#   inflating: espnet-pr-numpy/espnet2/layers/create_adapter.py
#   inflating: espnet-pr-numpy/espnet2/layers/create_adapter_fn.py
#   inflating: espnet-pr-numpy/espnet2/layers/create_adapter_utils.py
#   inflating: espnet-pr-numpy/espnet2/layers/global_mvn.py
#   inflating: espnet-pr-numpy/espnet2/layers/houlsby_adapter_layer.py
#   inflating: espnet-pr-numpy/espnet2/layers/inversible_interface.py
#   inflating: espnet-pr-numpy/espnet2/layers/label_aggregation.py
#   inflating: espnet-pr-numpy/espnet2/layers/log_mel.py
#   inflating: espnet-pr-numpy/espnet2/layers/mask_along_axis.py
#   inflating: espnet-pr-numpy/espnet2/layers/mixup_augmentation.py
#   inflating: espnet-pr-numpy/espnet2/layers/sinc_conv.py
#   inflating: espnet-pr-numpy/espnet2/layers/stft.py
#   inflating: espnet-pr-numpy/espnet2/layers/time_warp.py
#   inflating: espnet-pr-numpy/espnet2/layers/utterance_mvn.py
#    creating: espnet-pr-numpy/espnet2/lid/
#  extracting: espnet-pr-numpy/espnet2/lid/__init__.py
#   inflating: espnet-pr-numpy/espnet2/lid/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/lm/
#  extracting: espnet-pr-numpy/espnet2/lm/__init__.py
#   inflating: espnet-pr-numpy/espnet2/lm/abs_model.py
#   inflating: espnet-pr-numpy/espnet2/lm/espnet_model.py
#   inflating: espnet-pr-numpy/espnet2/lm/espnet_model_multitask.py
#   inflating: espnet-pr-numpy/espnet2/lm/huggingface_pretrained_opt_lm.py
#   inflating: espnet-pr-numpy/espnet2/lm/seq_rnn_lm.py
#   inflating: espnet-pr-numpy/espnet2/lm/transformer_lm.py
#    creating: espnet-pr-numpy/espnet2/main_funcs/
#  extracting: espnet-pr-numpy/espnet2/main_funcs/__init__.py
#   inflating: espnet-pr-numpy/espnet2/main_funcs/average_nbest_models.py
#   inflating: espnet-pr-numpy/espnet2/main_funcs/calculate_all_attentions.py
#   inflating: espnet-pr-numpy/espnet2/main_funcs/collect_stats.py
#   inflating: espnet-pr-numpy/espnet2/main_funcs/pack_funcs.py
#    creating: espnet-pr-numpy/espnet2/mt/
#  extracting: espnet-pr-numpy/espnet2/mt/__init__.py
#   inflating: espnet-pr-numpy/espnet2/mt/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/mt/frontend/
#  extracting: espnet-pr-numpy/espnet2/mt/frontend/__init__.py
#   inflating: espnet-pr-numpy/espnet2/mt/frontend/embedding.py
#    creating: espnet-pr-numpy/espnet2/optimizers/
#  extracting: espnet-pr-numpy/espnet2/optimizers/__init__.py
#   inflating: espnet-pr-numpy/espnet2/optimizers/optim_groups.py
#   inflating: espnet-pr-numpy/espnet2/optimizers/sgd.py
#    creating: espnet-pr-numpy/espnet2/s2st/
#  extracting: espnet-pr-numpy/espnet2/s2st/__init__.py
#    creating: espnet-pr-numpy/espnet2/s2st/aux_attention/
#  extracting: espnet-pr-numpy/espnet2/s2st/aux_attention/__init__.py
#   inflating: espnet-pr-numpy/espnet2/s2st/aux_attention/abs_aux_attention.py
#   inflating: espnet-pr-numpy/espnet2/s2st/aux_attention/multihead.py
#   inflating: espnet-pr-numpy/espnet2/s2st/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/s2st/losses/
#  extracting: espnet-pr-numpy/espnet2/s2st/losses/__init__.py
#   inflating: espnet-pr-numpy/espnet2/s2st/losses/abs_loss.py
#   inflating: espnet-pr-numpy/espnet2/s2st/losses/attention_loss.py
#   inflating: espnet-pr-numpy/espnet2/s2st/losses/ctc_loss.py
#   inflating: espnet-pr-numpy/espnet2/s2st/losses/guided_attention_loss.py
#   inflating: espnet-pr-numpy/espnet2/s2st/losses/tacotron_loss.py
#    creating: espnet-pr-numpy/espnet2/s2st/synthesizer/
#  extracting: espnet-pr-numpy/espnet2/s2st/synthesizer/__init__.py
#   inflating: espnet-pr-numpy/espnet2/s2st/synthesizer/abs_synthesizer.py
#   inflating: espnet-pr-numpy/espnet2/s2st/synthesizer/discrete_synthesizer.py
#   inflating: espnet-pr-numpy/espnet2/s2st/synthesizer/translatotron.py
#   inflating: espnet-pr-numpy/espnet2/s2st/synthesizer/translatotron2.py
#   inflating: espnet-pr-numpy/espnet2/s2st/synthesizer/unity_synthesizer.py
#    creating: espnet-pr-numpy/espnet2/s2st/tgt_feats_extract/
#  extracting: espnet-pr-numpy/espnet2/s2st/tgt_feats_extract/__init__.py
#   inflating: espnet-pr-numpy/espnet2/s2st/tgt_feats_extract/abs_tgt_feats_extract.py
#   inflating: espnet-pr-numpy/espnet2/s2st/tgt_feats_extract/linear_spectrogram.py
#   inflating: espnet-pr-numpy/espnet2/s2st/tgt_feats_extract/log_mel_fbank.py
#   inflating: espnet-pr-numpy/espnet2/s2st/tgt_feats_extract/log_spectrogram.py
#    creating: espnet-pr-numpy/espnet2/s2t/
#  extracting: espnet-pr-numpy/espnet2/s2t/__init__.py
#   inflating: espnet-pr-numpy/espnet2/s2t/espnet_ctc_model.py
#   inflating: espnet-pr-numpy/espnet2/s2t/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/samplers/
#  extracting: espnet-pr-numpy/espnet2/samplers/__init__.py
#   inflating: espnet-pr-numpy/espnet2/samplers/abs_sampler.py
#   inflating: espnet-pr-numpy/espnet2/samplers/build_batch_sampler.py
#   inflating: espnet-pr-numpy/espnet2/samplers/category_balanced_sampler.py
#   inflating: espnet-pr-numpy/espnet2/samplers/folded_batch_sampler.py
#   inflating: espnet-pr-numpy/espnet2/samplers/length_batch_sampler.py
#   inflating: espnet-pr-numpy/espnet2/samplers/num_elements_batch_sampler.py
#   inflating: espnet-pr-numpy/espnet2/samplers/sorted_batch_sampler.py
#   inflating: espnet-pr-numpy/espnet2/samplers/unsorted_batch_sampler.py
#    creating: espnet-pr-numpy/espnet2/schedulers/
#  extracting: espnet-pr-numpy/espnet2/schedulers/__init__.py
#   inflating: espnet-pr-numpy/espnet2/schedulers/abs_scheduler.py
#   inflating: espnet-pr-numpy/espnet2/schedulers/cosine_anneal_warmup_restart.py
#   inflating: espnet-pr-numpy/espnet2/schedulers/exponential_decay_warmup.py
#   inflating: espnet-pr-numpy/espnet2/schedulers/noam_lr.py
#   inflating: espnet-pr-numpy/espnet2/schedulers/piecewise_linear_warmup_lr.py
#   inflating: espnet-pr-numpy/espnet2/schedulers/warmup_lr.py
#   inflating: espnet-pr-numpy/espnet2/schedulers/warmup_reducelronplateau.py
#   inflating: espnet-pr-numpy/espnet2/schedulers/warmup_step_lr.py
#    creating: espnet-pr-numpy/espnet2/sds/
#  extracting: espnet-pr-numpy/espnet2/sds/__init__.py
#    creating: espnet-pr-numpy/espnet2/sds/asr/
#  extracting: espnet-pr-numpy/espnet2/sds/asr/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/asr/abs_asr.py
#   inflating: espnet-pr-numpy/espnet2/sds/asr/espnet_asr.py
#   inflating: espnet-pr-numpy/espnet2/sds/asr/owsm_asr.py
#   inflating: espnet-pr-numpy/espnet2/sds/asr/owsm_ctc_asr.py
#   inflating: espnet-pr-numpy/espnet2/sds/asr/whisper_asr.py
#    creating: espnet-pr-numpy/espnet2/sds/end_to_end/
#  extracting: espnet-pr-numpy/espnet2/sds/end_to_end/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/abs_e2e.py
#    creating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/README.md
#  extracting: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/inference.py
#    creating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/config.py
#    creating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/generate/
#  extracting: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/generate/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/generate/base.py
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/model.py
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/tokenizer.py
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/litgpt/utils.py
#    creating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/utils/
#  extracting: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/utils/__init__.py
#    creating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/utils/assets/
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/utils/assets/silero_vad.onnx
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni/utils/snac_utils.py
#   inflating: espnet-pr-numpy/espnet2/sds/end_to_end/mini_omni_e2e.py
#   inflating: espnet-pr-numpy/espnet2/sds/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/sds/llm/
#  extracting: espnet-pr-numpy/espnet2/sds/llm/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/llm/abs_llm.py
#   inflating: espnet-pr-numpy/espnet2/sds/llm/hugging_face_llm.py
#    creating: espnet-pr-numpy/espnet2/sds/tts/
#  extracting: espnet-pr-numpy/espnet2/sds/tts/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/tts/abs_tts.py
#   inflating: espnet-pr-numpy/espnet2/sds/tts/chat_tts.py
#   inflating: espnet-pr-numpy/espnet2/sds/tts/espnet_tts.py
#    creating: espnet-pr-numpy/espnet2/sds/utils/
#  extracting: espnet-pr-numpy/espnet2/sds/utils/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/utils/chat.py
#   inflating: espnet-pr-numpy/espnet2/sds/utils/utils.py
#    creating: espnet-pr-numpy/espnet2/sds/vad/
#  extracting: espnet-pr-numpy/espnet2/sds/vad/__init__.py
#   inflating: espnet-pr-numpy/espnet2/sds/vad/abs_vad.py
#   inflating: espnet-pr-numpy/espnet2/sds/vad/webrtc_vad.py
#    creating: espnet-pr-numpy/espnet2/slu/
#  extracting: espnet-pr-numpy/espnet2/slu/__init__.py
#   inflating: espnet-pr-numpy/espnet2/slu/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/slu/postdecoder/
#  extracting: espnet-pr-numpy/espnet2/slu/postdecoder/__init__.py
#   inflating: espnet-pr-numpy/espnet2/slu/postdecoder/abs_postdecoder.py
#   inflating: espnet-pr-numpy/espnet2/slu/postdecoder/hugging_face_transformers_postdecoder.py
#    creating: espnet-pr-numpy/espnet2/slu/postencoder/
#  extracting: espnet-pr-numpy/espnet2/slu/postencoder/__init__.py
#   inflating: espnet-pr-numpy/espnet2/slu/postencoder/conformer_postencoder.py
#   inflating: espnet-pr-numpy/espnet2/slu/postencoder/transformer_postencoder.py
#    creating: espnet-pr-numpy/espnet2/spk/
#  extracting: espnet-pr-numpy/espnet2/spk/__init__.py
#    creating: espnet-pr-numpy/espnet2/spk/encoder/
#  extracting: espnet-pr-numpy/espnet2/spk/encoder/__init__.py
#   inflating: espnet-pr-numpy/espnet2/spk/encoder/conformer_encoder.py
#   inflating: espnet-pr-numpy/espnet2/spk/encoder/ecapa_tdnn_encoder.py
#   inflating: espnet-pr-numpy/espnet2/spk/encoder/identity_encoder.py
#   inflating: espnet-pr-numpy/espnet2/spk/encoder/rawnet3_encoder.py
#   inflating: espnet-pr-numpy/espnet2/spk/encoder/resnet_encoder.py
#   inflating: espnet-pr-numpy/espnet2/spk/encoder/ska_tdnn_encoder.py
#   inflating: espnet-pr-numpy/espnet2/spk/encoder/xvector_encoder.py
#   inflating: espnet-pr-numpy/espnet2/spk/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/spk/layers/
#  extracting: espnet-pr-numpy/espnet2/spk/layers/__init__.py
#   inflating: espnet-pr-numpy/espnet2/spk/layers/ecapa_block.py
#   inflating: espnet-pr-numpy/espnet2/spk/layers/rawnet_block.py
#   inflating: espnet-pr-numpy/espnet2/spk/layers/resnet_block.py
#    creating: espnet-pr-numpy/espnet2/spk/loss/
#  extracting: espnet-pr-numpy/espnet2/spk/loss/__init__.py
#   inflating: espnet-pr-numpy/espnet2/spk/loss/aamsoftmax.py
#   inflating: espnet-pr-numpy/espnet2/spk/loss/aamsoftmax_subcenter_intertopk.py
#   inflating: espnet-pr-numpy/espnet2/spk/loss/abs_loss.py
#   inflating: espnet-pr-numpy/espnet2/spk/loss/softmax.py
#    creating: espnet-pr-numpy/espnet2/spk/pooling/
#  extracting: espnet-pr-numpy/espnet2/spk/pooling/__init__.py
#   inflating: espnet-pr-numpy/espnet2/spk/pooling/abs_pooling.py
#   inflating: espnet-pr-numpy/espnet2/spk/pooling/chn_attn_stat_pooling.py
#   inflating: espnet-pr-numpy/espnet2/spk/pooling/mean_pooling.py
#   inflating: espnet-pr-numpy/espnet2/spk/pooling/stat_pooling.py
#    creating: espnet-pr-numpy/espnet2/spk/projector/
#  extracting: espnet-pr-numpy/espnet2/spk/projector/__init__.py
#   inflating: espnet-pr-numpy/espnet2/spk/projector/abs_projector.py
#   inflating: espnet-pr-numpy/espnet2/spk/projector/rawnet3_projector.py
#   inflating: espnet-pr-numpy/espnet2/spk/projector/ska_tdnn_projector.py
#   inflating: espnet-pr-numpy/espnet2/spk/projector/xvector_projector.py
#    creating: espnet-pr-numpy/espnet2/ssl/
#  extracting: espnet-pr-numpy/espnet2/ssl/__init__.py
#   inflating: espnet-pr-numpy/espnet2/ssl/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/ssl/loss/
#  extracting: espnet-pr-numpy/espnet2/ssl/loss/__init__.py
#   inflating: espnet-pr-numpy/espnet2/ssl/loss/abs_loss.py
#   inflating: espnet-pr-numpy/espnet2/ssl/loss/hubert.py
#    creating: espnet-pr-numpy/espnet2/ssl/utils/
#  extracting: espnet-pr-numpy/espnet2/ssl/utils/__init__.py
#   inflating: espnet-pr-numpy/espnet2/ssl/utils/mask.py
#    creating: espnet-pr-numpy/espnet2/st/
#  extracting: espnet-pr-numpy/espnet2/st/__init__.py
#   inflating: espnet-pr-numpy/espnet2/st/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/svs/
#  extracting: espnet-pr-numpy/espnet2/svs/__init__.py
#   inflating: espnet-pr-numpy/espnet2/svs/abs_svs.py
#    creating: espnet-pr-numpy/espnet2/svs/discrete/
#  extracting: espnet-pr-numpy/espnet2/svs/discrete/__init__.py
#   inflating: espnet-pr-numpy/espnet2/svs/discrete/frontend.py
#   inflating: espnet-pr-numpy/espnet2/svs/discrete/loss.py
#   inflating: espnet-pr-numpy/espnet2/svs/discrete/toksing.py
#   inflating: espnet-pr-numpy/espnet2/svs/discrete_svs_espnet_model.py
#   inflating: espnet-pr-numpy/espnet2/svs/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/svs/feats_extract/
#  extracting: espnet-pr-numpy/espnet2/svs/feats_extract/__init__.py
#   inflating: espnet-pr-numpy/espnet2/svs/feats_extract/score_feats_extract.py
#    creating: espnet-pr-numpy/espnet2/svs/naive_rnn/
#  extracting: espnet-pr-numpy/espnet2/svs/naive_rnn/__init__.py
#   inflating: espnet-pr-numpy/espnet2/svs/naive_rnn/naive_rnn.py
#   inflating: espnet-pr-numpy/espnet2/svs/naive_rnn/naive_rnn_dp.py
#    creating: espnet-pr-numpy/espnet2/svs/singing_tacotron/
#  extracting: espnet-pr-numpy/espnet2/svs/singing_tacotron/__init__.py
#   inflating: espnet-pr-numpy/espnet2/svs/singing_tacotron/decoder.py
#   inflating: espnet-pr-numpy/espnet2/svs/singing_tacotron/encoder.py
#   inflating: espnet-pr-numpy/espnet2/svs/singing_tacotron/singing_tacotron.py
#    creating: espnet-pr-numpy/espnet2/svs/xiaoice/
#   inflating: espnet-pr-numpy/espnet2/svs/xiaoice/XiaoiceSing.py
#  extracting: espnet-pr-numpy/espnet2/svs/xiaoice/__init__.py
#   inflating: espnet-pr-numpy/espnet2/svs/xiaoice/loss.py
#    creating: espnet-pr-numpy/espnet2/tasks/
#  extracting: espnet-pr-numpy/espnet2/tasks/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tasks/abs_task.py
#   inflating: espnet-pr-numpy/espnet2/tasks/asr.py
#   inflating: espnet-pr-numpy/espnet2/tasks/asr_transducer.py
#   inflating: espnet-pr-numpy/espnet2/tasks/asvspoof.py
#   inflating: espnet-pr-numpy/espnet2/tasks/cls.py
#   inflating: espnet-pr-numpy/espnet2/tasks/diar.py
#   inflating: espnet-pr-numpy/espnet2/tasks/enh.py
#   inflating: espnet-pr-numpy/espnet2/tasks/enh_s2t.py
#   inflating: espnet-pr-numpy/espnet2/tasks/enh_tse.py
#   inflating: espnet-pr-numpy/espnet2/tasks/gan_codec.py
#   inflating: espnet-pr-numpy/espnet2/tasks/gan_svs.py
#   inflating: espnet-pr-numpy/espnet2/tasks/gan_tts.py
#   inflating: espnet-pr-numpy/espnet2/tasks/hubert.py
#   inflating: espnet-pr-numpy/espnet2/tasks/lid.py
#   inflating: espnet-pr-numpy/espnet2/tasks/lm.py
#   inflating: espnet-pr-numpy/espnet2/tasks/mt.py
#   inflating: espnet-pr-numpy/espnet2/tasks/s2st.py
#   inflating: espnet-pr-numpy/espnet2/tasks/s2t.py
#   inflating: espnet-pr-numpy/espnet2/tasks/s2t_ctc.py
#   inflating: espnet-pr-numpy/espnet2/tasks/slu.py
#   inflating: espnet-pr-numpy/espnet2/tasks/spk.py
#   inflating: espnet-pr-numpy/espnet2/tasks/ssl.py
#   inflating: espnet-pr-numpy/espnet2/tasks/st.py
#   inflating: espnet-pr-numpy/espnet2/tasks/svs.py
#   inflating: espnet-pr-numpy/espnet2/tasks/tts.py
#   inflating: espnet-pr-numpy/espnet2/tasks/tts2.py
#   inflating: espnet-pr-numpy/espnet2/tasks/uasr.py
#    creating: espnet-pr-numpy/espnet2/text/
#  extracting: espnet-pr-numpy/espnet2/text/__init__.py
#   inflating: espnet-pr-numpy/espnet2/text/abs_tokenizer.py
#   inflating: espnet-pr-numpy/espnet2/text/build_tokenizer.py
#   inflating: espnet-pr-numpy/espnet2/text/char_tokenizer.py
#   inflating: espnet-pr-numpy/espnet2/text/cleaner.py
#   inflating: espnet-pr-numpy/espnet2/text/hugging_face_token_id_converter.py
#   inflating: espnet-pr-numpy/espnet2/text/hugging_face_tokenizer.py
#   inflating: espnet-pr-numpy/espnet2/text/korean_cleaner.py
#   inflating: espnet-pr-numpy/espnet2/text/phoneme_tokenizer.py
#   inflating: espnet-pr-numpy/espnet2/text/sentencepiece_tokenizer.py
#   inflating: espnet-pr-numpy/espnet2/text/token_id_converter.py
#   inflating: espnet-pr-numpy/espnet2/text/whisper_token_id_converter.py
#   inflating: espnet-pr-numpy/espnet2/text/whisper_tokenizer.py
#   inflating: espnet-pr-numpy/espnet2/text/word_tokenizer.py
#    creating: espnet-pr-numpy/espnet2/torch_utils/
#  extracting: espnet-pr-numpy/espnet2/torch_utils/__init__.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/add_gradient_noise.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/device_funcs.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/forward_adaptor.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/get_flash_attn_compatability.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/get_layer_from_string.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/initialize.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/load_pretrained_model.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/model_summary.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/pytorch_version.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/recursive_op.py
#   inflating: espnet-pr-numpy/espnet2/torch_utils/set_all_random_seed.py
#    creating: espnet-pr-numpy/espnet2/train/
#  extracting: espnet-pr-numpy/espnet2/train/__init__.py
#   inflating: espnet-pr-numpy/espnet2/train/abs_espnet_model.py
#   inflating: espnet-pr-numpy/espnet2/train/abs_gan_espnet_model.py
#   inflating: espnet-pr-numpy/espnet2/train/class_choices.py
#   inflating: espnet-pr-numpy/espnet2/train/collate_fn.py
#   inflating: espnet-pr-numpy/espnet2/train/dataset.py
#   inflating: espnet-pr-numpy/espnet2/train/deepspeed_trainer.py
#   inflating: espnet-pr-numpy/espnet2/train/distributed_utils.py
#   inflating: espnet-pr-numpy/espnet2/train/gan_trainer.py
#   inflating: espnet-pr-numpy/espnet2/train/iterable_dataset.py
#   inflating: espnet-pr-numpy/espnet2/train/lid_trainer.py
#   inflating: espnet-pr-numpy/espnet2/train/lightning_callbacks.py
#   inflating: espnet-pr-numpy/espnet2/train/lightning_espnet_model.py
#   inflating: espnet-pr-numpy/espnet2/train/preprocessor.py
#   inflating: espnet-pr-numpy/espnet2/train/reporter.py
#   inflating: espnet-pr-numpy/espnet2/train/spk_trainer.py
#   inflating: espnet-pr-numpy/espnet2/train/trainer.py
#   inflating: espnet-pr-numpy/espnet2/train/uasr_trainer.py
#    creating: espnet-pr-numpy/espnet2/tts/
#  extracting: espnet-pr-numpy/espnet2/tts/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/abs_tts.py
#   inflating: espnet-pr-numpy/espnet2/tts/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/tts/fastspeech/
#   inflating: espnet-pr-numpy/espnet2/tts/fastspeech/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/fastspeech/fastspeech.py
#    creating: espnet-pr-numpy/espnet2/tts/fastspeech2/
#   inflating: espnet-pr-numpy/espnet2/tts/fastspeech2/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/fastspeech2/fastspeech2.py
#   inflating: espnet-pr-numpy/espnet2/tts/fastspeech2/loss.py
#   inflating: espnet-pr-numpy/espnet2/tts/fastspeech2/variance_predictor.py
#    creating: espnet-pr-numpy/espnet2/tts/feats_extract/
#  extracting: espnet-pr-numpy/espnet2/tts/feats_extract/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/feats_extract/abs_feats_extract.py
#   inflating: espnet-pr-numpy/espnet2/tts/feats_extract/dio.py
#   inflating: espnet-pr-numpy/espnet2/tts/feats_extract/energy.py
#   inflating: espnet-pr-numpy/espnet2/tts/feats_extract/linear_spectrogram.py
#   inflating: espnet-pr-numpy/espnet2/tts/feats_extract/log_mel_fbank.py
#   inflating: espnet-pr-numpy/espnet2/tts/feats_extract/log_spectrogram.py
#   inflating: espnet-pr-numpy/espnet2/tts/feats_extract/yin.py
#   inflating: espnet-pr-numpy/espnet2/tts/feats_extract/ying.py
#    creating: espnet-pr-numpy/espnet2/tts/gst/
#  extracting: espnet-pr-numpy/espnet2/tts/gst/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/gst/style_encoder.py
#    creating: espnet-pr-numpy/espnet2/tts/prodiff/
#   inflating: espnet-pr-numpy/espnet2/tts/prodiff/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/prodiff/denoiser.py
#   inflating: espnet-pr-numpy/espnet2/tts/prodiff/loss.py
#   inflating: espnet-pr-numpy/espnet2/tts/prodiff/prodiff.py
#    creating: espnet-pr-numpy/espnet2/tts/tacotron2/
#   inflating: espnet-pr-numpy/espnet2/tts/tacotron2/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/tacotron2/tacotron2.py
#    creating: espnet-pr-numpy/espnet2/tts/transformer/
#   inflating: espnet-pr-numpy/espnet2/tts/transformer/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/transformer/transformer.py
#    creating: espnet-pr-numpy/espnet2/tts/utils/
#   inflating: espnet-pr-numpy/espnet2/tts/utils/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts/utils/duration_calculator.py
#   inflating: espnet-pr-numpy/espnet2/tts/utils/parallel_wavegan_pretrained_vocoder.py
#    creating: espnet-pr-numpy/espnet2/tts2/
#  extracting: espnet-pr-numpy/espnet2/tts2/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts2/abs_tts2.py
#   inflating: espnet-pr-numpy/espnet2/tts2/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/tts2/fastspeech2/
#   inflating: espnet-pr-numpy/espnet2/tts2/fastspeech2/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts2/fastspeech2/fastspeech2_discrete.py
#   inflating: espnet-pr-numpy/espnet2/tts2/fastspeech2/loss.py
#    creating: espnet-pr-numpy/espnet2/tts2/feats_extract/
#  extracting: espnet-pr-numpy/espnet2/tts2/feats_extract/__init__.py
#   inflating: espnet-pr-numpy/espnet2/tts2/feats_extract/abs_feats_extract.py
#   inflating: espnet-pr-numpy/espnet2/tts2/feats_extract/identity.py
#    creating: espnet-pr-numpy/espnet2/uasr/
#  extracting: espnet-pr-numpy/espnet2/uasr/__init__.py
#    creating: espnet-pr-numpy/espnet2/uasr/discriminator/
#  extracting: espnet-pr-numpy/espnet2/uasr/discriminator/__init__.py
#   inflating: espnet-pr-numpy/espnet2/uasr/discriminator/abs_discriminator.py
#   inflating: espnet-pr-numpy/espnet2/uasr/discriminator/conv_discriminator.py
#   inflating: espnet-pr-numpy/espnet2/uasr/espnet_model.py
#    creating: espnet-pr-numpy/espnet2/uasr/generator/
#  extracting: espnet-pr-numpy/espnet2/uasr/generator/__init__.py
#   inflating: espnet-pr-numpy/espnet2/uasr/generator/abs_generator.py
#   inflating: espnet-pr-numpy/espnet2/uasr/generator/conv_generator.py
#    creating: espnet-pr-numpy/espnet2/uasr/loss/
#  extracting: espnet-pr-numpy/espnet2/uasr/loss/__init__.py
#   inflating: espnet-pr-numpy/espnet2/uasr/loss/abs_loss.py
#   inflating: espnet-pr-numpy/espnet2/uasr/loss/discriminator_loss.py
#   inflating: espnet-pr-numpy/espnet2/uasr/loss/gradient_penalty.py
#   inflating: espnet-pr-numpy/espnet2/uasr/loss/phoneme_diversity_loss.py
#   inflating: espnet-pr-numpy/espnet2/uasr/loss/pseudo_label_loss.py
#   inflating: espnet-pr-numpy/espnet2/uasr/loss/smoothness_penalty.py
#    creating: espnet-pr-numpy/espnet2/uasr/segmenter/
#  extracting: espnet-pr-numpy/espnet2/uasr/segmenter/__init__.py
#   inflating: espnet-pr-numpy/espnet2/uasr/segmenter/abs_segmenter.py
#   inflating: espnet-pr-numpy/espnet2/uasr/segmenter/join_segmenter.py
#   inflating: espnet-pr-numpy/espnet2/uasr/segmenter/random_segmenter.py
#    creating: espnet-pr-numpy/espnet2/utils/
#  extracting: espnet-pr-numpy/espnet2/utils/__init__.py
#   inflating: espnet-pr-numpy/espnet2/utils/build_dataclass.py
#   inflating: espnet-pr-numpy/espnet2/utils/config_argparse.py
#   inflating: espnet-pr-numpy/espnet2/utils/eer.py
#   inflating: espnet-pr-numpy/espnet2/utils/get_default_kwargs.py
#   inflating: espnet-pr-numpy/espnet2/utils/griffin_lim.py
#   inflating: espnet-pr-numpy/espnet2/utils/kwargs2args.py
#   inflating: espnet-pr-numpy/espnet2/utils/nested_dict_action.py
#   inflating: espnet-pr-numpy/espnet2/utils/sized_dict.py
#   inflating: espnet-pr-numpy/espnet2/utils/types.py
#   inflating: espnet-pr-numpy/espnet2/utils/yaml_no_alias_safe_dump.py
#    creating: espnet-pr-numpy/espnetez/
#   inflating: espnet-pr-numpy/espnetez/__init__.py
#   inflating: espnet-pr-numpy/espnetez/config.py
#    creating: espnet-pr-numpy/espnetez/data/
#  extracting: espnet-pr-numpy/espnetez/data/__init__.py
#   inflating: espnet-pr-numpy/espnetez/data/dump.py
#   inflating: espnet-pr-numpy/espnetez/dataloader.py
#   inflating: espnet-pr-numpy/espnetez/dataset.py
#    creating: espnet-pr-numpy/espnetez/preprocess/
#   inflating: espnet-pr-numpy/espnetez/preprocess/__init__.py
#   inflating: espnet-pr-numpy/espnetez/preprocess/sentencepiece.py
#   inflating: espnet-pr-numpy/espnetez/preprocess/tokenizer.py
#   inflating: espnet-pr-numpy/espnetez/task.py
#   inflating: espnet-pr-numpy/espnetez/trainer.py
#   inflating: espnet-pr-numpy/setup.cfg
#   inflating: espnet-pr-numpy/setup.py
#    creating: espnet-pr-numpy/test/
#  extracting: espnet-pr-numpy/test/__init__.py
#   inflating: espnet-pr-numpy/test/beam_search_test.arpa
#    creating: espnet-pr-numpy/test/espnet2/
#  extracting: espnet-pr-numpy/test/espnet2/__init__.py
#    creating: espnet-pr-numpy/test/espnet2/asr/
#  extracting: espnet-pr-numpy/test/espnet2/asr/__init__.py
#    creating: espnet-pr-numpy/test/espnet2/asr/decoder/
#  extracting: espnet-pr-numpy/test/espnet2/asr/decoder/__init__.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/decoder/test_hugging_face_transformers_decoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/decoder/test_linear_decoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/decoder/test_mlm_decoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/decoder/test_rnn_decoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/decoder/test_s4_decoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/decoder/test_transducer_decoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/decoder/test_transformer_decoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/decoder/test_whisper_decoder.py
#    creating: espnet-pr-numpy/test/espnet2/asr/encoder/
#  extracting: espnet-pr-numpy/test/espnet2/asr/encoder/__init__.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_avhubert_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_beats_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_branchformer_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_conformer_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_contextual_block_transformer_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_e_branchformer_ctc_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_e_branchformer_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_hubert_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_longformer_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_multiconvformer_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_rnn_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_transformer_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_transformer_encoder_multispkr.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_vgg_rnn_encoder.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/encoder/test_whisper_encoder.py
#    creating: espnet-pr-numpy/test/espnet2/asr/frontend/
#  extracting: espnet-pr-numpy/test/espnet2/asr/frontend/__init__.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/frontend/test_asteroid.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/frontend/test_espnet_ssl.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/frontend/test_frontend.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/frontend/test_fused.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/frontend/test_melspec_torch.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/frontend/test_s3prl.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/frontend/test_transformers.py
#   inflating: espnet-pr-numpy/test/espnet2/asr/frontend/test_whisper.py
# ...
#   espnet-pr-numpy/egs2/wsj/asr1/conf/train_lm_rnn.yaml -> tuning/train_lm_adam_layers4.yaml
#   espnet-pr-numpy/egs2/wsj/asr1/conf/train_lm_transformer.yaml -> tuning/train_lm_transformer.yaml
#   espnet-pr-numpy/egs2/wsj/asr1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/wsj/asr1/local/find_transcripts.pl -> ../../../../egs/wsj/asr1/local/find_transcripts.pl
#   espnet-pr-numpy/egs2/wsj/asr1/local/flist2scp.pl -> ../../../../egs/wsj/asr1/local/flist2scp.pl
#   espnet-pr-numpy/egs2/wsj/asr1/local/ndx2flist.pl -> ../../../../egs/wsj/asr1/local/ndx2flist.pl
#   espnet-pr-numpy/egs2/wsj/asr1/local/normalize_transcript.pl -> ../../../../egs/wsj/asr1/local/normalize_transcript.pl
#   espnet-pr-numpy/egs2/wsj/asr1/local/wsj_data_prep.sh -> ../../../../egs/wsj/asr1/local/wsj_data_prep.sh
#   espnet-pr-numpy/egs2/wsj/asr1/local/wsj_format_data.sh -> ../../../../egs/wsj/asr1/local/wsj_format_data.sh
#   espnet-pr-numpy/egs2/wsj/asr1/path.sh -> ../../TEMPLATE/asr1/path.sh
#   espnet-pr-numpy/egs2/wsj/asr1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj/asr1/scripts -> ../../TEMPLATE/asr1/scripts
#   espnet-pr-numpy/egs2/wsj/asr1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/wsj/asr1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/conf/train.yaml -> tuning/train_enh_rnn_tf.yaml
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/enh.sh -> ../../TEMPLATE/enh1/enh.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/local/find_transcripts.pl -> ../../../../egs/wsj/asr1/local/find_transcripts.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/local/flist2scp.pl -> ../../../../egs/wsj/asr1/local/flist2scp.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/local/ndx2flist.pl -> ../../../../egs/wsj/asr1/local/ndx2flist.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/local/normalize_transcript.pl -> ../../../../egs/wsj/asr1/local/normalize_transcript.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/local/wsj_data_prep.sh -> ../../../../egs/wsj/asr1/local/wsj_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/local/wsj_format_data.sh -> ../../../../egs/wsj/asr1/local/wsj_format_data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/path.sh -> ../../TEMPLATE/enh1/path.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/scripts -> ../../TEMPLATE/enh1/scripts
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/wsj0_2mix/enh1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/conf/train.yaml -> tuning/train_enh_conv_tasnet.yaml
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/enh.sh -> ../../TEMPLATE/enh1/enh.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/convert2wav.sh -> ../../enh1/local/convert2wav.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/data_supervised.sh -> ../../enh1/local/data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/find_transcripts.pl -> ../../../../egs/wsj/asr1/local/find_transcripts.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/flist2scp.pl -> ../../../../egs/wsj/asr1/local/flist2scp.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/ndx2flist.pl -> ../../../../egs/wsj/asr1/local/ndx2flist.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/normalize_transcript.pl -> ../../../../egs/wsj/asr1/local/normalize_transcript.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/wsj0_2mix_data_prep.sh -> ../../enh1/local/wsj0_2mix_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/wsj0_create_mixture.sh -> ../../enh1/local/wsj0_create_mixture.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/wsj_data_prep.sh -> ../../../../egs/wsj/asr1/local/wsj_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/local/wsj_format_data.sh -> ../../../../egs/wsj/asr1/local/wsj_format_data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/path.sh -> ../../TEMPLATE/enh1/path.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/scripts -> ../../TEMPLATE/enh1/scripts
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/wsj0_2mix/mixit_enh1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/conf/train.yaml -> tuning/train_enh_tse_td_speakerbeam.yaml
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/enh.sh -> ../../TEMPLATE/enh1/enh.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/local/data.sh -> ../../../wsj0_2mix/enh1/local/data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/local/find_transcripts.pl -> ../../../../egs/wsj/asr1/local/find_transcripts.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/local/flist2scp.pl -> ../../../../egs/wsj/asr1/local/flist2scp.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/local/ndx2flist.pl -> ../../../../egs/wsj/asr1/local/ndx2flist.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/local/normalize_transcript.pl -> ../../../../egs/wsj/asr1/local/normalize_transcript.pl
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/local/wsj0_create_mixture.sh -> ../../../wsj0_2mix/enh1/local/wsj0_create_mixture.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/local/wsj_data_prep.sh -> ../../../../egs/wsj/asr1/local/wsj_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/local/wsj_format_data.sh -> ../../../../egs/wsj/asr1/local/wsj_format_data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/path.sh -> ../../TEMPLATE/enh1/path.sh
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/scripts -> ../../TEMPLATE/enh1/scripts
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/steps -> ../../../tools/kaldi/egs/wsj/s5/steps
#   espnet-pr-numpy/egs2/wsj0_2mix/tse1/utils -> ../../../tools/kaldi/egs/wsj/s5/utils
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/conf/train.yaml -> tuning/train_enh_beamformer_no_wpe.yaml
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/enh.sh -> ../../TEMPLATE/enh1/enh.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/convert2wav.sh -> ../../../wsj0_2mix/enh1/local/convert2wav.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/find_transcripts.pl -> ../../../../egs/wsj/asr1/local/find_transcripts.pl
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/flist2scp.pl -> ../../../../egs/wsj/asr1/local/flist2scp.pl
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/ndx2flist.pl -> ../../../../egs/wsj/asr1/local/ndx2flist.pl
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/normalize_transcript.pl -> ../../../../egs/wsj/asr1/local/normalize_transcript.pl
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/wsj0_2mix_data.sh -> ../../../wsj0_2mix/enh1/local/data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/wsj0_2mix_data_prep.sh -> ../../../wsj0_2mix/enh1/local/wsj0_2mix_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/wsj0_create_mixture.sh -> ../../../wsj0_2mix/enh1/local/wsj0_create_mixture.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/wsj_data_prep.sh -> ../../../../egs/wsj/asr1/local/wsj_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/local/wsj_format_data.sh -> ../../../../egs/wsj/asr1/local/wsj_format_data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/path.sh -> ../../TEMPLATE/enh1/path.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/scripts -> ../../TEMPLATE/enh1/scripts
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/conf/train.yaml -> tuning/train_enh_asr_beamformer_fbank_transformer.yaml
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/db.sh -> ../../TEMPLATE/enh_asr1/db.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/enh_asr.sh -> ../../TEMPLATE/enh_asr1/enh_asr.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/convert2wav.sh -> ../../../wsj0_2mix/enh1/local/convert2wav.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/enh_data.sh -> ../../../wsj0_2mix_spatialized/enh1/local/data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/find_transcripts.pl -> ../../../../egs/wsj/asr1/local/find_transcripts.pl
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/flist2scp.pl -> ../../../../egs/wsj/asr1/local/flist2scp.pl
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/ndx2flist.pl -> ../../../../egs/wsj/asr1/local/ndx2flist.pl
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/normalize_transcript.pl -> ../../../../egs/wsj/asr1/local/normalize_transcript.pl
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/spatialize_wsj0_mix.sh -> ../../../wsj0_2mix_spatialized/enh1/local/spatialize_wsj0_mix.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/wsj0_2mix_data.sh -> ../../../wsj0_2mix/enh1/local/data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/wsj0_2mix_data_prep.sh -> ../../../wsj0_2mix/enh1/local/wsj0_2mix_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/wsj0_2mix_spatialized_data_prep.sh -> ../../../wsj0_2mix_spatialized/enh1/local/wsj0_2mix_spatialized_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/wsj0_create_mixture.sh -> ../../../wsj0_2mix/enh1/local/wsj0_create_mixture.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/wsj_data_prep.sh -> ../../../../egs/wsj/asr1/local/wsj_data_prep.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/local/wsj_format_data.sh -> ../../../../egs/wsj/asr1/local/wsj_format_data.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/path.sh -> ../../TEMPLATE/enh_asr1/path.sh
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/pyscripts -> ../../TEMPLATE/enh_asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/scripts -> ../../TEMPLATE/enh_asr1/scripts
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/wsj0_2mix_spatialized/enh_asr1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/wsj0_chime3/enh1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/wsj0_chime3/enh1/enh.sh -> ../../TEMPLATE/enh1/enh.sh
#   espnet-pr-numpy/egs2/wsj0_chime3/enh1/local/convert2wav.sh -> ../../../wsj0_2mix/enh1/local/convert2wav.sh
#   espnet-pr-numpy/egs2/wsj0_chime3/enh1/path.sh -> ../../TEMPLATE/enh1/path.sh
#   espnet-pr-numpy/egs2/wsj0_chime3/enh1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj0_chime3/enh1/scripts -> ../../TEMPLATE/enh1/scripts
#   espnet-pr-numpy/egs2/wsj0_chime3/enh1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/wsj0_chime3/enh1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/wsj0_reverb/enh1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/wsj0_reverb/enh1/enh.sh -> ../../TEMPLATE/enh1/enh.sh
#   espnet-pr-numpy/egs2/wsj0_reverb/enh1/local/convert2wav.sh -> ../../../wsj0_2mix/enh1/local/convert2wav.sh
#   espnet-pr-numpy/egs2/wsj0_reverb/enh1/path.sh -> ../../TEMPLATE/enh1/path.sh
#   espnet-pr-numpy/egs2/wsj0_reverb/enh1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj0_reverb/enh1/scripts -> ../../TEMPLATE/enh1/scripts
#   espnet-pr-numpy/egs2/wsj0_reverb/enh1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/wsj0_reverb/enh1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/wsj_kinect/enh1/conf/train.yaml -> tuning/train_enh_tfgridnetv2_tf_lr-patience3_patience5_I_1_J_1_D_128_batch_8.yaml
#   espnet-pr-numpy/egs2/wsj_kinect/enh1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/wsj_kinect/enh1/enh.sh -> ../../TEMPLATE/enh1/enh.sh
#   espnet-pr-numpy/egs2/wsj_kinect/enh1/path.sh -> ../../TEMPLATE/enh1/path.sh
#   espnet-pr-numpy/egs2/wsj_kinect/enh1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/wsj_kinect/enh1/scripts -> ../../TEMPLATE/enh1/scripts
#   espnet-pr-numpy/egs2/wsj_kinect/enh1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/wsj_kinect/enh1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/yesno/asr1/asr.sh -> ../../TEMPLATE/asr1/asr.sh
#   espnet-pr-numpy/egs2/yesno/asr1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/yesno/asr1/local/create_yesno_txt.pl -> ../../../../egs/yesno/asr1/local/create_yesno_txt.pl
#   espnet-pr-numpy/egs2/yesno/asr1/local/create_yesno_wav_scp.pl -> ../../../../egs/yesno/asr1/local/create_yesno_wav_scp.pl
#   espnet-pr-numpy/egs2/yesno/asr1/local/create_yesno_waves_test_train.pl -> ../../../../egs/yesno/asr1/local/create_yesno_waves_test_train.pl
#   espnet-pr-numpy/egs2/yesno/asr1/path.sh -> ../../TEMPLATE/asr1/path.sh
#   espnet-pr-numpy/egs2/yesno/asr1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/yesno/asr1/scripts -> ../../TEMPLATE/asr1/scripts
#   espnet-pr-numpy/egs2/yesno/asr1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/yesno/asr1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/asr.sh -> ../../TEMPLATE/asr1/asr.sh
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/conf/decode_asr.yaml -> tuning/decode_transformer.yaml
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/conf/train_asr.yaml -> tuning/train_asr_transformer.yaml
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/local/data_prep.py -> ../../../../egs/yoloxochitl_mixtec/asr1/local/data_prep.py
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/local/download_and_untar.sh -> ../../../../egs/yoloxochitl_mixtec/asr1/local/download_and_untar.sh
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/local/split_tr_dt_et.sh -> ../../../../egs/yoloxochitl_mixtec/asr1/local/split_tr_dt_et.sh
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/path.sh -> ../../TEMPLATE/asr1/path.sh
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/scripts -> ../../TEMPLATE/asr1/scripts
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/yoloxochitl_mixtec/asr1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/asr.sh -> ../../TEMPLATE/asr1/asr.sh
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/conf/train_asr_rnn.yaml -> tuning/train_asr_rnn.yaml
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/conf/train_asr_transformer.yaml -> tuning/train_asr_transformer3.yaml
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/conf/train_lm.yaml -> tuning/train_lm.yaml
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/path.sh -> ../../TEMPLATE/asr1/path.sh
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/scripts -> ../../TEMPLATE/asr1/scripts
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/zeroth_korean/asr1/utils -> ../../TEMPLATE/asr1/utils
#   espnet-pr-numpy/egs2/zh_openslr38/asr1/asr.sh -> ../../TEMPLATE/asr1/asr.sh
#   espnet-pr-numpy/egs2/zh_openslr38/asr1/db.sh -> ../../TEMPLATE/asr1/db.sh
#   espnet-pr-numpy/egs2/zh_openslr38/asr1/path.sh -> ../../TEMPLATE/asr1/path.sh
#   espnet-pr-numpy/egs2/zh_openslr38/asr1/pyscripts -> ../../TEMPLATE/asr1/pyscripts
#   espnet-pr-numpy/egs2/zh_openslr38/asr1/scripts -> ../../TEMPLATE/asr1/scripts
#   espnet-pr-numpy/egs2/zh_openslr38/asr1/steps -> ../../TEMPLATE/asr1/steps
#   espnet-pr-numpy/egs2/zh_openslr38/asr1/utils -> ../../TEMPLATE/asr1/utils

# %%
# !cd espnet-pr-numpy && pip install .
# Out:
# Processing /content/espnet-pr-numpy
#   Preparing metadata (setup.py) ... done
# Collecting g2p_en@ git+https://github.com/espnet/g2p.git@master (from espnet==202506)
#   Cloning https://github.com/espnet/g2p.git (to revision master) to /tmp/pip-install-j09u5ran/g2p-en_ddea8b1da65d4eedb58653152e45e244
#   Running command git clone --filter=blob:none --quiet https://github.com/espnet/g2p.git /tmp/pip-install-j09u5ran/g2p-en_ddea8b1da65d4eedb58653152e45e244
#   Resolved https://github.com/espnet/g2p.git to commit 053dfa94811efc6370bbdb0ff9777be4a5cb0b84
#   Preparing metadata (setup.py) ... done
# Collecting ctc-segmentation@ git+https://github.com/espnet/ctc-segmentation.git@9b9ea1d (from espnet==202506)
#   Cloning https://github.com/espnet/ctc-segmentation.git (to revision 9b9ea1d) to /tmp/pip-install-j09u5ran/ctc-segmentation_f4251a1cedec428ba208172abcfb6559
#   Running command git clone --filter=blob:none --quiet https://github.com/espnet/ctc-segmentation.git /tmp/pip-install-j09u5ran/ctc-segmentation_f4251a1cedec428ba208172abcfb6559
#   WARNING: Did not find branch or tag '9b9ea1d', assuming revision or ref.
#   Running command git checkout -q 9b9ea1d
#   Resolved https://github.com/espnet/ctc-segmentation.git to commit 9b9ea1d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting setuptools<74.0.0,>=38.5.1 (from espnet==202506)
#   Downloading setuptools-73.0.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (25.0)
# Collecting configargparse>=1.2.1 (from espnet==202506)
#   Downloading configargparse-1.7.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (4.4.4)
# Collecting humanfriendly (from espnet==202506)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (1.16.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (3.19.1)
# Requirement already satisfied: librosa>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (0.11.0)
# Collecting jamo==0.4.1 (from espnet==202506)
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: PyYAML>=5.1.2 in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (6.0.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (0.13.1)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (3.14.0)
# Collecting kaldiio>=2.18.0 (from espnet==202506)
#   Downloading kaldiio-2.18.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (2.8.0+cu126)
# Collecting torch_complex (from espnet==202506)
#   Downloading torch_complex-0.4.4-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (3.9.1)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (2.0.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (5.29.5)
# Collecting hydra-core (from espnet==202506)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (3.4.0)
# Collecting lightning (from espnet==202506)
#   Downloading lightning-2.5.3-py3-none-any.whl.metadata (39 kB)
# Collecting sentencepiece==0.2.0 (from espnet==202506)
#   Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting pyworld>=0.3.4 (from espnet==202506)
#   Downloading pyworld-0.3.5.tar.gz (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 13.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pypinyin<=0.44.0 (from espnet==202506)
#   Downloading pypinyin-0.44.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting espnet_tts_frontend (from espnet==202506)
#   Downloading espnet_tts_frontend-0.0.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting ci_sdr (from espnet==202506)
#   Downloading ci_sdr-0.0.2.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fast-bss-eval==0.1.3 (from espnet==202506)
#   Downloading fast_bss_eval-0.1.3.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting asteroid_filterbanks==0.4.0 (from espnet==202506)
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.12/dist-packages (from espnet==202506) (0.8.1)
# Collecting importlib-metadata<5.0 (from espnet==202506)
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from asteroid_filterbanks==0.4.0->espnet==202506) (4.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<5.0->espnet==202506) (3.23.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet==202506) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.4.5->espnet==202506) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.4.5->espnet==202506) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.4.5->espnet==202506) (4.67.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.2->espnet==202506) (1.17.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet==202506) (3.4.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from ci_sdr->espnet==202506) (0.8.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from ctc-segmentation@ git+https://github.com/espnet/ctc-segmentation.git@9b9ea1d->espnet==202506) (3.0.12)
# Collecting unidecode>=1.0.22 (from espnet_tts_frontend->espnet==202506)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: inflect>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from espnet_tts_frontend->espnet==202506) (7.5.0)
# Collecting jaconv (from espnet_tts_frontend->espnet==202506)
#   Downloading jaconv-0.4.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting distance>=0.1.3 (from g2p_en@ git+https://github.com/espnet/g2p.git@master->espnet==202506)
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 16.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core->espnet==202506) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->espnet==202506) (4.9.3)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning->espnet==202506)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning->espnet==202506)
#   Downloading torchmetrics-1.8.1-py3-none-any.whl.metadata (22 kB)
# Collecting pytorch-lightning (from lightning->espnet==202506)
#   Downloading pytorch_lightning-2.5.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.2->espnet==202506) (2.22)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->espnet==202506) (3.12.15)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from inflect>=1.0.0->espnet_tts_frontend->espnet==202506) (10.7.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa>=0.10.2->espnet==202506) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.10.2->espnet==202506) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.10.2->espnet==202506) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa>=0.10.2->espnet==202506) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->espnet==202506) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->espnet==202506) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet==202506) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet==202506) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet==202506) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet==202506) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet==202506) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet==202506) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet==202506) (1.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.2->espnet==202506) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.2->espnet==202506) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.2->espnet==202506) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.2->espnet==202506) (2025.8.3)
# Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Downloading sentencepiece-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.2 MB/s eta 0:00:00
# Downloading configargparse-1.7.1-py3-none-any.whl (25 kB)
# Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Downloading kaldiio-2.18.1-py3-none-any.whl (29 kB)
# Downloading pypinyin-0.44.0-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.6 MB/s eta 0:00:00
# Downloading setuptools-73.0.1-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 100.2 MB/s eta 0:00:00
# Downloading espnet_tts_frontend-0.0.3-py3-none-any.whl (11 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.0 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.2 MB/s eta 0:00:00
# Downloading lightning-2.5.3-py3-none-any.whl (824 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.2/824.2 kB 62.1 MB/s eta 0:00:00
# Downloading torch_complex-0.4.4-py3-none-any.whl (9.1 kB)
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.1-py3-none-any.whl (982 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.0/983.0 kB 71.9 MB/s eta 0:00:00
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 25.5 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.3-py3-none-any.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.2/828.2 kB 50.5 MB/s eta 0:00:00
# Building wheels for collected packages: espnet, fast-bss-eval, pyworld, ci_sdr, ctc-segmentation, g2p_en, distance, jaconv
#   Building wheel for espnet (setup.py) ... done
#   Created wheel for espnet: filename=espnet-202506-py3-none-any.whl size=2170194 sha256=0b3b26134ad8245d025aecad257e172c074a00c8679711c6ba024f8e7eb0f41f
#   Stored in directory: /root/.cache/pip/wheels/19/ec/f2/dcc1cb44e595a9a1647d1d37509797a38b5653c76c59264902
#   Building wheel for fast-bss-eval (setup.py) ... done
#   Created wheel for fast-bss-eval: filename=fast_bss_eval-0.1.3-py3-none-any.whl size=44242 sha256=220bb27bb4b2166b50dc757facc9f1faa60715911c6bb193b145bdeb1e6a0e8f
#   Stored in directory: /root/.cache/pip/wheels/fb/df/41/09574538cada21f186358a411d1631fe0a0de4bf3252547965
#   Building wheel for pyworld (pyproject.toml) ... done
#   Created wheel for pyworld: filename=pyworld-0.3.5-cp312-cp312-linux_x86_64.whl size=966260 sha256=28ecf365be92153f03537d6ea03263fcb60d3621b47942770b0e597c483ad155
#   Stored in directory: /root/.cache/pip/wheels/be/ac/58/c6a1791ec6d17f3a99b6ccdec92b472f560cb5c564b83dd77e
#   Building wheel for ci_sdr (setup.py) ... done
#   Created wheel for ci_sdr: filename=ci_sdr-0.0.2-py3-none-any.whl size=15252 sha256=5adfcd2650a8ec085fdbcad99b1db87bbf0191ca65a7aeac301cfd5b983bef45
#   Stored in directory: /root/.cache/pip/wheels/58/15/dd/e2ccfd74b12c8da89f3b9899d2f6fb433ae187d6c3d8d51bdd
#   Building wheel for ctc-segmentation (pyproject.toml) ... done
#   Created wheel for ctc-segmentation: filename=ctc_segmentation-1.7.5-cp312-cp312-linux_x86_64.whl size=165042 sha256=67584eb87be2db294edc541c865a29fe46e33134a3ceee6103276bea9c02fd95
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ijokpdg8/wheels/74/36/58/3a04873f3f04ffec0c50fbdcb1c770aca38c836d9e31acdd1c
#   Building wheel for g2p_en (setup.py) ... done
#   Created wheel for g2p_en: filename=g2p_en-2.0.0-py3-none-any.whl size=3117448 sha256=ea63765777d979b1be4f82e50fa4b7b01c003a06d7f8516a8c22578c6193b733
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ijokpdg8/wheels/f3/99/dc/3f16fb4cc53ea4c3a435255f79467c03dda9aced6ba73f58ac
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16256 sha256=97b89a6be3e37651bfd4caedfaff0e3a4e82372abbe6592f87df37201fa52243
#   Stored in directory: /root/.cache/pip/wheels/24/a8/58/407063d8e5c1d4dd6594c99d12baa0108570b56a92325587dd
#   Building wheel for jaconv (setup.py) ... done
#   Created wheel for jaconv: filename=jaconv-0.4.0-py3-none-any.whl size=18228 sha256=10606498206a7a4755c259f4ef18aaa40bd674c5b3425c0df4e5c6f74605e665
#   Stored in directory: /root/.cache/pip/wheels/c9/97/53/1f827ebf916b899520ce663227497206525c432be72cc29265
# Successfully built espnet fast-bss-eval pyworld ci_sdr ctc-segmentation g2p_en distance jaconv
# Installing collected packages: sentencepiece, jamo, jaconv, distance, unidecode, torch_complex, setuptools, pyworld, pypinyin, kaldiio, importlib-metadata, humanfriendly, configargparse, lightning-utilities, hydra-core, fast-bss-eval, ctc-segmentation, g2p_en, torchmetrics, espnet_tts_frontend, ci_sdr, asteroid_filterbanks, pytorch-lightning, lightning, espnet
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.1
#     Uninstalling sentencepiece-0.2.1:
#       Successfully uninstalled sentencepiece-0.2.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.7.0
#     Uninstalling importlib_metadata-8.7.0:
#       Successfully uninstalled importlib_metadata-8.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# opentelemetry-api 1.36.0 requires importlib-metadata<8.8.0,>=6.0, but you have importlib-metadata 4.13.0 which is incompatible.
# Successfully installed asteroid_filterbanks-0.4.0 ci_sdr-0.0.2 configargparse-1.7.1 ctc-segmentation-1.7.5 distance-0.1.3 espnet-202506 espnet_tts_frontend-0.0.3 fast-bss-eval-0.1.3 g2p_en-2.0.0 humanfriendly-10.0 hydra-core-1.3.2 importlib-metadata-4.13.0 jaconv-0.4.0 jamo-0.4.1 kaldiio-2.18.1 lightning-2.5.3 lightning-utilities-0.15.2 pypinyin-0.44.0 pytorch-lightning-2.5.3 pyworld-0.3.5 sentencepiece-0.2.0 setuptools-73.0.1 torch_complex-0.4.4 torchmetrics-1.8.1 unidecode-1.4.0

# %%
# !pip install espnet-model-zoo # for downloading pre-trained models
# !apt install ffmpeg # for audio file processing
# !pip install ipywebrtc notebook # for real-time recording
# Out:
# Collecting espnet-model-zoo
#   Downloading espnet_model_zoo-0.1.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from espnet-model-zoo) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from espnet-model-zoo) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from espnet-model-zoo) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from espnet-model-zoo) (2.0.2)
# Requirement already satisfied: espnet in /usr/local/lib/python3.12/dist-packages (from espnet-model-zoo) (202506)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from espnet-model-zoo) (0.34.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from espnet-model-zoo) (3.19.1)
# Collecting g2p-en@ git+https://github.com/espnet/g2p.git@master (from espnet->espnet-model-zoo)
#   Cloning https://github.com/espnet/g2p.git (to revision master) to /tmp/pip-install-i241f35g/g2p-en_86aadfe387f74e2b8156c422360d8065
#   Running command git clone --filter=blob:none --quiet https://github.com/espnet/g2p.git /tmp/pip-install-i241f35g/g2p-en_86aadfe387f74e2b8156c422360d8065
#   Resolved https://github.com/espnet/g2p.git to commit 053dfa94811efc6370bbdb0ff9777be4a5cb0b84
#   Preparing metadata (setup.py) ... done
# Collecting ctc-segmentation@ git+https://github.com/espnet/ctc-segmentation.git@9b9ea1d (from espnet->espnet-model-zoo)
#   Cloning https://github.com/espnet/ctc-segmentation.git (to revision 9b9ea1d) to /tmp/pip-install-i241f35g/ctc-segmentation_8f22c73461974587a97686756d080bb5
#   Running command git clone --filter=blob:none --quiet https://github.com/espnet/ctc-segmentation.git /tmp/pip-install-i241f35g/ctc-segmentation_8f22c73461974587a97686756d080bb5
#   WARNING: Did not find branch or tag '9b9ea1d', assuming revision or ref.
#   Running command git checkout -q 9b9ea1d
#   Resolved https://github.com/espnet/ctc-segmentation.git to commit 9b9ea1d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools<74.0.0,>=38.5.1 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (73.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (25.0)
# Requirement already satisfied: configargparse>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (1.7.1)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (4.4.4)
# Requirement already satisfied: humanfriendly in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (10.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (1.16.1)
# Requirement already satisfied: librosa>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.11.0)
# Requirement already satisfied: jamo==0.4.1 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.4.1)
# Requirement already satisfied: PyYAML>=5.1.2 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (6.0.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.13.1)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (3.14.0)
# Requirement already satisfied: kaldiio>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (2.18.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (2.8.0+cu126)
# Requirement already satisfied: torch-complex in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.4.4)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (3.9.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (5.29.5)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (1.3.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (3.4.0)
# Requirement already satisfied: lightning in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (2.5.3)
# Requirement already satisfied: sentencepiece==0.2.0 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.2.0)
# Requirement already satisfied: pyworld>=0.3.4 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.3.5)
# Requirement already satisfied: pypinyin<=0.44.0 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.44.0)
# Requirement already satisfied: espnet-tts-frontend in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.0.3)
# Requirement already satisfied: ci-sdr in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.0.2)
# Requirement already satisfied: fast-bss-eval==0.1.3 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.1.3)
# Requirement already satisfied: asteroid-filterbanks==0.4.0 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.4.0)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (0.8.1)
# Requirement already satisfied: importlib-metadata<5.0 in /usr/local/lib/python3.12/dist-packages (from espnet->espnet-model-zoo) (4.13.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from asteroid-filterbanks==0.4.0->espnet->espnet-model-zoo) (4.15.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->espnet-model-zoo) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->espnet-model-zoo) (1.1.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->espnet-model-zoo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->espnet-model-zoo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->espnet-model-zoo) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->espnet-model-zoo) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->espnet-model-zoo) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->espnet-model-zoo) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->espnet-model-zoo) (2025.8.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<5.0->espnet->espnet-model-zoo) (3.23.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa>=0.10.2->espnet->espnet-model-zoo) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.4.5->espnet->espnet-model-zoo) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.4.5->espnet->espnet-model-zoo) (2024.11.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->espnet-model-zoo) (1.17.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.2->espnet->espnet-model-zoo) (1.17.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->espnet->espnet-model-zoo) (3.4.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from ci-sdr->espnet->espnet-model-zoo) (0.8.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from ctc-segmentation@ git+https://github.com/espnet/ctc-segmentation.git@9b9ea1d->espnet->espnet-model-zoo) (3.0.12)
# Requirement already satisfied: unidecode>=1.0.22 in /usr/local/lib/python3.12/dist-packages (from espnet-tts-frontend->espnet->espnet-model-zoo) (1.4.0)
# Requirement already satisfied: inflect>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from espnet-tts-frontend->espnet->espnet-model-zoo) (7.5.0)
# Requirement already satisfied: jaconv in /usr/local/lib/python3.12/dist-packages (from espnet-tts-frontend->espnet->espnet-model-zoo) (0.4.0)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from g2p-en@ git+https://github.com/espnet/g2p.git@master->espnet->espnet-model-zoo) (0.1.3)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core->espnet->espnet-model-zoo) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->espnet->espnet-model-zoo) (4.9.3)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning->espnet->espnet-model-zoo) (0.15.2)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /usr/local/lib/python3.12/dist-packages (from lightning->espnet->espnet-model-zoo) (1.8.1)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning->espnet->espnet-model-zoo) (2.5.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.2->espnet->espnet-model-zoo) (2.22)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->espnet->espnet-model-zoo) (3.12.15)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from inflect>=1.0.0->espnet-tts-frontend->espnet->espnet-model-zoo) (10.7.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa>=0.10.2->espnet->espnet-model-zoo) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa>=0.10.2->espnet->espnet-model-zoo) (4.3.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa>=0.10.2->espnet->espnet-model-zoo) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->espnet->espnet-model-zoo) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->espnet->espnet-model-zoo) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet->espnet-model-zoo) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet->espnet-model-zoo) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet->espnet-model-zoo) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet->espnet-model-zoo) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet->espnet-model-zoo) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet->espnet-model-zoo) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->espnet->espnet-model-zoo) (1.20.1)
# Downloading espnet_model_zoo-0.1.7-py3-none-any.whl (19 kB)
# Installing collected packages: espnet-model-zoo
# Successfully installed espnet-model-zoo-0.1.7
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Collecting ipywebrtc
#   Downloading ipywebrtc-0.6.0-py2.py3-none-any.whl.metadata (825 bytes)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (6.5.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from notebook) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from notebook) (26.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook) (25.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from notebook) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.12/dist-packages (from notebook) (5.8.1)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.12/dist-packages (from notebook) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.12/dist-packages (from notebook) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from notebook) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-client<8,>=5.3.4->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.6.1->notebook) (4.3.8)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (0.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (25.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook) (2.19.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook) (4.25.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook) (25.1.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook) (0.1.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook) (5.9.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook) (1.4.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook) (73.0.1)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->notebook)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook) (0.27.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook) (1.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.1->jupyter-client<8,>=5.3.4->notebook) (1.17.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook) (0.8.5)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook) (4.10.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook) (1.8.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook) (0.2.13)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook) (1.3.1)
# Downloading ipywebrtc-0.6.0-py2.py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.7/260.7 kB 10.5 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.0 MB/s eta 0:00:00
# Installing collected packages: ipywebrtc, jedi
# Successfully installed ipywebrtc-0.6.0 jedi-0.19.2

# %% [markdown]
# ### Import the dependencies and check the state of installation

# %%
# !pip install datasets==3.6.0
# Out:
# Collecting datasets==3.6.0
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.34.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (1.1.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.6.0) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 11.2 MB/s eta 0:00:00
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed datasets-3.6.0

# %%
import torch
import datasets
import espnetez as ez # ESPnet wrapper that simplifies integration. If you get an error when executing this cell, click Runtime -> Restart Session, and rerun from the beginning
import numpy as np
import librosa
from espnet2.bin.s2t_inference import Speech2Text # Core ESPnet module for pre-trained models

print("Installation success!")
# Out:
# Failed to import Flash Attention, using ESPnet default: No module named 'flash_attn'
# /usr/local/lib/python3.12/dist-packages/espnet2/enh/encoder/stft_encoder.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# /usr/local/lib/python3.12/dist-packages/espnet2/enh/layers/uses2_swin.py:329: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast(enabled=False)
# Installation success!

# %% [markdown]
# ## Data Processing
# For this tutorial, we will use the [FLEURS](https://arxiv.org/abs/2205.12446) dataset from HuggingFace: https://huggingface.co/datasets/google/fleurs .
#
# FLEURS is a 102-language multilingual speech dataset, supporting tasks such as Automatic Speech Recognition (ASR), Speech Translation (ST), and Language Identification (LID).
#
# While the total size of FLEURS is relatively large at ~1000 hours of training data, each individual language only has 7-10 hours of audio.
#
# For this tutorial, we will focus on monolingual ASR for one of the 102 languages.

# %% [markdown]
# ### Data Downloading
# We will first download the data for one language of FLEURS. FLEURS organizes the languages by its ISO2 language code and locale. For example, American English is `en_us`.
#
# **We will use English for the first fine-tuning experiment.** You will have the opportunity to try a different language later on in the assignment.
#
# If you want to download the data for another language, you can map the language name to the ISO2 code using Table 9 in the FLEURS paper: https://arxiv.org/pdf/2205.12446. Then, you can use that to identify the language+region combination using the HuggingFace data previewer: https://huggingface.co/datasets/google/fleurs .
#
# (Please select y for the prompt of running custom code to download the data)

# %%
fleurs_language = 'en_us' # fleurs language codes are in the <language code>_<region code> format.
fleurs_hf = datasets.load_dataset("google/fleurs", fleurs_language)
# Out:
# The repository for google/fleurs contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/google/fleurs.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# data/en_us/audio/train.tar.gz:   0%|          | 0.00/1.38G [00:00<?, ?B/s]
# data/en_us/audio/dev.tar.gz:   0%|          | 0.00/171M [00:00<?, ?B/s]
# data/en_us/audio/test.tar.gz:   0%|          | 0.00/290M [00:00<?, ?B/s]
# train.tsv: 0.00B [00:00, ?B/s]
# dev.tsv: 0.00B [00:00, ?B/s]
# test.tsv: 0.00B [00:00, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ### Inspect the data

# %%
fleurs_hf['train'][0]
# Out:
# {'id': 903,
#  'num_samples': 108800,
#  'path': '/root/.cache/huggingface/datasets/downloads/extracted/be467d88ba270014363a9d0aaae3893b4701a2710e0a55c6091a6d4fa56a9d84/10004088536354799741.wav',
#  'audio': {'path': 'train/10004088536354799741.wav',
#   'array': array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          -3.15904617e-06, -3.03983688e-06, -3.27825546e-06]),
#   'sampling_rate': 16000},
#  'transcription': 'a tornado is a spinning column of very low-pressure air which sucks the surrounding air inward and upward',
#  'raw_transcription': 'A tornado is a spinning column of very low-pressure air, which sucks the surrounding air inward and upward.',
#  'gender': 1,
#  'lang_id': 19,
#  'language': 'English',
#  'lang_group_id': 0}

# %%
from IPython.display import Audio, display
display(Audio(fleurs_hf['train'][0]['audio']['array'], rate=16000))
print(fleurs_hf['train'][0]['transcription'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# a tornado is a spinning column of very low-pressure air which sucks the surrounding air inward and upward

# %% [markdown]
# ## Pretrained Model
# In low-resource settings, training a model from scratch is unlikely to lead to good results. So instead, we will fine-tune a pre-trained foundation model.
#
# We will use the base version of [OWSM 3.1](https://arxiv.org/pdf/2401.16658), an open-source speech foundation model trained on 180K hours of multilingual ASR and ST.

# %% [markdown]
# ### Downloading
# Since it needs to support many language varieties, OWSM uses ISO3 for the language IDs. The ISO3 code for your language of choice can also be found in Table 9 in the FLEURS paper: https://arxiv.org/pdf/2205.12446

# %%
FINETUNE_MODEL="espnet/owsm_v3.1_ebf_base"
owsm_language="eng" # language code in ISO3

# %%
pretrained_model = Speech2Text.from_pretrained(
    FINETUNE_MODEL,
    lang_sym=f"<{owsm_language}>",
    beam_size=1,
    device='cuda'
)
torch.save(pretrained_model.s2t_model.state_dict(), 'original.pth')
pretrain_config = vars(pretrained_model.s2t_train_args)
tokenizer = pretrained_model.tokenizer
converter = pretrained_model.converter
# Out:
# Fetching 29 files:   0%|          | 0/29 [00:00<?, ?it/s]
# data/token_list/bpe_unigram50000/bpe.mod(…):   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# exp/s2t_stats_raw_bpe50000/train/feats_s(…):   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# config.yaml: 0.00B [00:00, ?B/s]
# acc.png:   0%|          | 0.00/33.1k [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# backward_time.png:   0%|          | 0.00/42.2k [00:00<?, ?B/s]
# RESULTS.md:   0%|          | 0.00/366 [00:00<?, ?B/s]
# cer.png:   0%|          | 0.00/28.5k [00:00<?, ?B/s]
# gpu_max_cached_mem_GB.png:   0%|          | 0.00/36.9k [00:00<?, ?B/s]
# forward_time.png:   0%|          | 0.00/48.7k [00:00<?, ?B/s]
# grad_norm.png:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# clip.png:   0%|          | 0.00/29.1k [00:00<?, ?B/s]
# cer_ctc.png:   0%|          | 0.00/26.6k [00:00<?, ?B/s]
# loss.png:   0%|          | 0.00/31.4k [00:00<?, ?B/s]
# optim0_lr0.png:   0%|          | 0.00/30.6k [00:00<?, ?B/s]
# loss_scale.png:   0%|          | 0.00/32.8k [00:00<?, ?B/s]
# loss_ctc.png:   0%|          | 0.00/34.5k [00:00<?, ?B/s]
# loss_att.png:   0%|          | 0.00/31.6k [00:00<?, ?B/s]
# iter_time.png:   0%|          | 0.00/41.8k [00:00<?, ?B/s]
# exp/s2t_train_s2t_ebf_conv2d_size384_e6_(…):   0%|          | 0.00/405M [00:00<?, ?B/s]
# optim_step_time.png:   0%|          | 0.00/33.8k [00:00<?, ?B/s]
# train_time.png:   0%|          | 0.00/40.3k [00:00<?, ?B/s]
# wer.png:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# train.log: 0.00B [00:00, ?B/s]
# train.1.log: 0.00B [00:00, ?B/s]
# train.2.log: 0.00B [00:00, ?B/s]
# train.3.log: 0.00B [00:00, ?B/s]
# meta.yaml:   0%|          | 0.00/422 [00:00<?, ?B/s]

# %% [markdown]
# ## Setup Training
# We first need to convert the HuggingFace data into a format that ESPnet can read. This can be easily done by defining a `data_info` dictionary that maps each field required for OWSM fine-tuning to a column in our dataset.

# %%
'''
pretrained_model -> the pre-trained model we downloaded earlier
tokenizer -> Tokenizes raw text into subwords
converter -> Converts subwords into integer IDs for model input
'''

def tokenize(text):
    return np.array(converter.tokens2ids(tokenizer.text2tokens(text)))
data_info = {
    "speech": lambda d: d['audio']['array'].astype(np.float32), # 1-D raw waveform
    "text": lambda d: tokenize(f"<{owsm_language}><asr><notimestamps> {d['transcription']}"), # tokenized text mapped to integer ids
    "text_prev": lambda d: tokenize("<na>"), # tokenized text of previous utterance for prompting, unused here
    "text_ctc": lambda d: tokenize(d['transcription']), # tokenized text mapped to integer ids for CTC loss, can be different from "text" depending on task
}
test_data_info = {
    "speech": lambda d: d['audio']['array'].astype(np.float32),
    "text": lambda d: tokenize(f"<{owsm_language}><asr><notimestamps> {d['transcription']}"),
    "text_prev": lambda d: tokenize("<na>"),
    "text_ctc": lambda d: tokenize(d['transcription']),
    "text_raw": lambda d: d['transcription'], # raw untokenized text as the reference
}
train_dataset = ez.dataset.ESPnetEZDataset(fleurs_hf['train'], data_info=data_info)
valid_dataset = ez.dataset.ESPnetEZDataset(fleurs_hf['validation'], data_info=data_info)
test_dataset = ez.dataset.ESPnetEZDataset(fleurs_hf['test'], data_info=test_data_info)

# %% [markdown]
# Next we need to define a function that will pass our pre-trained model to ESPnet. This function here doesn't do much since our setup is simple, but its required for more complex settings (such as LoRA fine-tuning).

# %%
# define model loading function
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def build_model_fn(args):
  model = pretrained_model.s2t_model
  model.train()
  print(f'Trainable parameters: {count_parameters(model)}')
  return model

# %% [markdown]
# ### Training
# Training requires tuning many hyper-parameters. Here is an initial config to start you off.

# %%
# !gdown 1Hp4hgtgdt84i4Qd99hW5ZM5aV743xN1U
# !mkdir config
# !mv finetune.yaml config/finetune.yaml
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Hp4hgtgdt84i4Qd99hW5ZM5aV743xN1U
# To: /content/finetune.yaml
# 100% 987/987 [00:00<00:00, 5.89MB/s]

# %% [markdown]
# Before we begin training, we need to define where our model files and logs will be saved. We also need to override some of the settings used to pre-train the foundation model with our own settings.

# %%
EXP_DIR = f"./exp/finetune"
STATS_DIR = f"./exp/stats_finetune"
finetune_config = ez.config.update_finetune_config(
	's2t',
	pretrain_config,
	f"./config/finetune.yaml"
)

# You can edit your config by changing the finetune.yaml file directly (but make sure you rerun this cell again!)
# You can also change it programatically like this
finetune_config['max_epoch'] = 1
finetune_config['num_iters_per_epoch'] = 500

# %% [markdown]
# Finally, we just need to pass our model, data, and configs to a trainer.

# %%
trainer = ez.Trainer(
    task='s2t',
    train_config=finetune_config,
    train_dataset=train_dataset,
    valid_dataset=valid_dataset,
    build_model_fn=build_model_fn, # provide the pre-trained model
    data_info=data_info,
    output_dir=EXP_DIR,
    stats_dir=STATS_DIR,
    ngpu=1
)

# %%
trainer.collect_stats() # collect audio/text length information to construct batches
# Out:
# /usr/bin/python3 /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-d46b9550-eb4f-43b9-adad-3129c1db55f8.json
# Trainable parameters: 101182628

# %%
trainer.train() # every 100 steps takes ~1 min
# Out:
# /usr/bin/python3 /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-d46b9550-eb4f-43b9-adad-3129c1db55f8.json
# Trainable parameters: 101182628
# /usr/local/lib/python3.12/dist-packages/espnet2/train/trainer.py:638: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(
# /usr/local/lib/python3.12/dist-packages/espnet2/s2t/espnet_model.py:279: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
# /usr/local/lib/python3.12/dist-packages/espnet2/train/trainer.py:856: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(

# %% [markdown]
# ## Inference
#
# Here is a demo of how to perform inference, and how to load checkpoints.

# %%
id, sample_test_utterance = test_dataset.__getitem__(0)

# %%
pretrained_model.s2t_model.cuda()
pretrained_model.device = 'cuda'

d = torch.load("original.pth")
pretrained_model.s2t_model.load_state_dict(d)
pred = pretrained_model(sample_test_utterance['speech'])
print('PREDICTED: ' + pred[0][0])
print('REFERENCE: ' + sample_test_utterance['text_raw'])
# Out:
# PREDICTED: <eng><asr><notimestamps> However, due to the slow communication channels, styles in the west could lag behind by twenty five to thirty years.
# REFERENCE: however due to the slow communication channels styles in the west could lag behind by 25 to 30 year

# %% [markdown]
# ### Inference with fine-tuned model

# %%
d = torch.load("./exp/finetune/1epoch.pth")
pretrained_model.s2t_model.load_state_dict(d)
pred = pretrained_model(sample_test_utterance['speech'])
print('PREDICTED: ' + pred[0][0])
print('REFERENCE: ' + sample_test_utterance['text_raw'])
# Out:
# PREDICTED: <eng><asr><notimestamps> however due to the slow communication channels styles in the west could lag behind by 25 to 30 years
# REFERENCE: however due to the slow communication channels styles in the west could lag behind by 25 to 30 year

# %% [markdown]
# ## ✅ Task 1
# Now that you have performed inference with both the pre-trained model and your fine-tuned model, provide some qualitative analyses of the results. How does the output between the two models differ? Do you observe any stylistic differences in the transcriptions?

# %% [markdown]
# (Your answer here)

# %% [markdown]
# ## ✅ Task 2
#
#
# A good way to understand the capabilities of neural models is to play with them yourself. Record a brief audio clip of yourself speaking. How accurately does the model transcribe your speech?
#
# Then, utter the same sentence, but vary some characteristics of your speech. For example, you can try speaking faster, in a different pitch, or in a different accent. How does the resulting transcription change?
#
# Finally, if the model made any mistakes in its transcriptions, why do you think these errors occured?

# %%
# You may need to run this cell twice before it will work the first time
# !rm recording.webm
# !rm recording.wav
from ipywebrtc import AudioRecorder, CameraStream
from google.colab import output
output.enable_custom_widget_manager()
mic = AudioRecorder(stream=CameraStream(constraints={'audio': True,'video':False}))
mic # press the circle to record, press it again to stop recording

# %%
with open('recording.webm', 'wb') as out_f:
    out_f.write(mic.audio.value)
audio, sr = librosa.load('recording.webm', sr=16000) # ASR typically uses 16kHz audio
pretrained_model(audio)[0][0]

# %% [markdown]
# (Your answer here)
